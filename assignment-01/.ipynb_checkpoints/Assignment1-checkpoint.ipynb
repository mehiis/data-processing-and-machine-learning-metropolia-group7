# %%
import pandas as pd

data = []
with open('chronic_kidney_disease_full.arff', "r") as f:
    for line in f:
        line = line.replace('\n', '')
        data.append(line.split(','))


names = ['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba',
         'bgr', 'bu',  'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc',
         'rbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane',
         'class', 'no_name']
    
df = pd.DataFrame(data[145:], columns=names)

df
# Out:
#     age   bp     sg   al   su     rbc        pc         pcc          ba  bgr  \
# 0    48   80  1.020    1    0       ?    normal  notpresent  notpresent  121
# 1     7   50  1.020    4    0       ?    normal  notpresent  notpresent    ?
# 2    62   80  1.010    2    3  normal    normal  notpresent  notpresent  423
# 3    48   70  1.005    4    0  normal  abnormal     present  notpresent  117
# 4    51   80  1.010    2    0  normal    normal  notpresent  notpresent  106
# ..   ..  ...    ...  ...  ...     ...       ...         ...         ...  ...
# 397  12   80  1.020    0    0  normal    normal  notpresent  notpresent  100
# 398  17   60  1.025    0    0  normal    normal  notpresent  notpresent  114
# 399  58   80  1.025    0    0  normal    normal  notpresent  notpresent  131
# 400      NaN    NaN  NaN  NaN     NaN       NaN         NaN         NaN  NaN
# 401      NaN    NaN  NaN  NaN     NaN       NaN         NaN         NaN  NaN
#
#      ...  wbcc rbcc  htn   dm  cad appet   pe  ane   class no_name
# 0    ...  7800  5.2  yes  yes   no  good   no   no     ckd     NaN
# 1    ...  6000    ?   no   no   no  good   no   no     ckd     NaN
# 2    ...  7500    ?   no  yes   no  poor   no  yes     ckd     NaN
# 3    ...  6700  3.9  yes   no   no  poor  yes  yes     ckd     NaN
# 4    ...  7300  4.6   no   no   no  good   no   no     ckd     NaN
# ..   ...   ...  ...  ...  ...  ...   ...  ...  ...     ...     ...
# 397  ...  6600  5.4   no   no   no  good   no   no  notckd     NaN
# 398  ...  7200  5.9   no   no   no  good   no   no  notckd     NaN
# 399  ...  6800  6.1   no   no   no  good   no   no  notckd     NaN
# 400  ...   NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN     NaN     NaN
# 401  ...   NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN     NaN     NaN
#
# [402 rows x 26 columns]
